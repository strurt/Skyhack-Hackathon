# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Survey data_Inflight Satisfaction Score.csv')

# %%
df['score'] = pd.to_numeric(df['score'], errors='coerce')

# %%
df = df[df['score'] > 3]

# %%
df.head()
# Out:
#     flight_number origin_station_code destination_station_code record_locator  \
# 1            4645                 COX                      DEX         DRXXMH
# 2            5236                 COX                      DEX         DEXXS1
# 4             671                 DEX                      COX         KZXXH5
# 6            3609                 EWX                      PHX         DPXXGS
# 25           5378                 ORX                      CIX         FNXX7N
#
#    scheduled_departure_date  \
# 1                  9/1/2022
# 2                  9/1/2022
# 4                  9/1/2022
# 6                  9/1/2022
# 25                 9/1/2022
#
#                                         question_text  score  \
# 1   How satisfied were you with the food & beverag...    5.0
# 2   How satisfied were you with the food & beverag...    5.0
# 4   How satisfied were you with the food & beverag...    5.0
# 6   How satisfied were you with the food & beverag...    5.0
# ...

# %%
df.sort_values(by=['flight_number', 'scheduled_departure_date'], inplace=True)

# %%
df.head()
# Out:
#        flight_number origin_station_code destination_station_code  \
# 17437              2                 SFX                      SIX
# 22182              2                 SFX                      SIX
# 30360              2                 SFX                      SIX
# 33473              2                 SFX                      SIX
# 34980              2                 SFX                      SIX
#
#       record_locator scheduled_departure_date  \
# 17437         HTXXVT                9/11/2022
# 22182         J1XXK4                9/14/2022
# 30360         LCXX6D                9/19/2022
# 33473         BTXX0S                9/21/2022
# 34980         P2XXJ3                9/22/2022
#
#                                            question_text  score  \
# 17437  How satisfied were you with the food & beverag...    4.0
# 22182  How satisfied were you with the food & beverag...    4.0
# 30360  How satisfied were you with the food & beverag...    4.0
# ...

# %%
num_satisfied_late = df[df['arrival_delay_minutes'] < 0].shape[0]
total_satisfied = df.shape[0]

# %%
percentage_satisfied_late = (num_satisfied_late / total_satisfied) * 100

# %%
percentage_satisfied_late
# Out:
# 71.6336241078509

# %%
labels = ['Satisfied Customers with Late Arrival', 'Satisfied Customers with Early Arrival']
sizes = [percentage_satisfied_late, 100 - percentage_satisfied_late]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  


plt.title('Satisfied customers and arrival')


plt.show()
